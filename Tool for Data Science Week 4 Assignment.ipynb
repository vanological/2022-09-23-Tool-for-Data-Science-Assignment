# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Van Chen**<br>
# Data Engineer

# %% [markdown]
# *I am interested in Data Science because it seems a skill quite suitable for self-study with abundant career prospects.  Needing only a laptop, internet connection, and some data sets, it is possible to build a working project.*

# %% [markdown]
# ### Python code that prints out current time.

# %%
import datetime
dt = datetime.datetime.now()
print(str(dt))
# Out:
# 2022-09-24 01:27:32.799931

# %% [markdown]
# [This is my favorite poem](https://www.poetryfoundation.org/poems/58713/defeat-56d23d566b4c3)
# ***
# `Above this sentence is a horizontal rule.`
# 1. So we begin with a hyperlink, that's one,
# 1. Then we have the horizontal rule, that's two,
# 1. Lastly there is the highlighted text,
# 1. Then I waste some time with this numbered list.
